# %%
# !uv pip install -q 'model-registry[olot]'

# %%
import os
from pathlib import Path

from model_registry.utils import save_to_oci_registry

# %%
# registry auth (i.e. instead of ~/.docker/config.json)
os.environ["REGISTRY_AUTH_FILE"] = "/tmp/auth.json"

# %%
model_path = Path.home() / "my-model"

# %%
save_to_oci_registry(
    base_image="quay.io/jburdo/busybox:latest",
    oci_ref="quay.io/jburdo/my-model:v1",
    model_files_path=model_path,
)
# Out:
# Copying blob sha256:a3b655d4356d3eafbfce127e94844901a68074eb6fde905780d46cabf0caf342
# Copying config sha256:af3f0f48a24edb84e94aff6f44f5d089203453719d3b2328486d311e61db9b09
# Writing manifest to image destination
# Getting image source signatures
# Copying blob sha256:a3b655d4356d3eafbfce127e94844901a68074eb6fde905780d46cabf0caf342
# Copying blob sha256:edf2ff9c0e867177ca5f6dffd2f6c424958754ebb69a88b19f4745f3b6b0bf84
# Copying blob sha256:ede8090f48cc68bdd54546a380d660437c933c1ddc4f9456fba863ec1e4fdd4c
# Copying blob sha256:b30d5ebdfed7178378d7aa58432edea156cee960a51b0c75fa24fe36fa64e889
# Copying blob sha256:36b5398d867f64a8cdeb20e924964bdae341c3a574e4ec01d6aec681187b9ea3
# Copying blob sha256:d202252cc075cd8d4df4dc4dafceddfe5611bb0721fc241d55c34102d0db0418
# Copying blob sha256:1574b22de85678bbad96e338d42e372878fb3b1182210ccfdd8824ad89750132
# Copying blob sha256:37cf13ffca4a8aaa5248ec012be8ebaf24d657d5925d07090f9e411699cdb981
# Copying blob sha256:bb084ac57878053e2c1c4443e044b115eb972231a94faf4baabdf1c4a8bc651b
# Copying blob sha256:b8e3a5c98082d2619221128ca2761155d6eb155476e567639900fa88ef2a3dcb
# Copying blob sha256:4030f7f19edf604eee2d52c5a50b2ce11cabd15a6544368434ea0d06c066dd87
# Copying blob sha256:ad9f569c6bed0ee32e172e3ef73ab21b9a68139bddd96eb3da17b064bbb792a7
# Copying blob sha256:77ac15a51e1b47a275b9a688e676295b459eb19673aaf01ac9ad250aa29b2191
# Copying blob sha256:08ae9aecba6207789358fe1b52a5ac9288d3d285e13efce7cc1739b81b463482
# Copying blob sha256:cbdf25e1021980210f3e6faeb0ca682c913679965d982e94b5cb8d8ed6bfd51e
# Copying blob sha256:7b7543937bbd8b12ee2d6e1d77850ecb5d1231ba878a4ed8bce50d964a722471
# Copying blob sha256:dacfb3562923a605597901f3ab4aa3bcf2b9f906f00cba7899137ef6d97d63ec
# Copying blob sha256:7ad8452912a3265e12433d79e816aa677c4354aedd6fa6a542396deefca6ed21
# Copying blob sha256:be0687a1ca755b42082ab2235979e551cd3efbbecd315c3ec693269a92bbc8e9
# Copying blob sha256:172b5675dca09db15ce3aa0ecd554bdd89095dd20dfc040688468e16574cedbe
# Copying blob sha256:bc6504245bb2177bf0d8a7bbb0e06cfe23216a62e08a086b74fbd31a99071e1d
# Copying blob sha256:881cd7512b77367f5a379cb0320ed202b84a2439ded1b38a29dc0e4923a8528a
# Copying blob sha256:de62c7a0efeb139c6a1febad52862e9d7c544158717e741085a919c097124193
# Copying blob sha256:e42a4d5b5397de870abe0085d86fa213c876ac6a16b48847fc3f473c3bf843fe
# Copying blob sha256:4bb100019e23cbbf6b0d27f7f0f5bfa7dab549a9cec4955e4aed55d405bbc1f5
# Copying blob sha256:21860c73d694d358d9f39ee16ec6c13f8c74689e5d3f7c49e29a2cb914fd4ba5
# Copying blob sha256:6345b08cb537c8af085330769cf25d52a130c6753e4dfbc198d44da1d46aa79e
# Copying blob sha256:8a0f9e5559547f51c44b7ffe384dc293ff7792ebef1da7b1b1d00cb97592a32f
# Copying blob sha256:06bc550d17ed21534a8fab908926a10796f773836b6cb49564f74c6d4b51deaf
# Copying blob sha256:63143b6216ac085df1b31bba21151e8ecf90c78d79039c5c937dd0e2e1c6451c
# Copying blob sha256:d959e1b390694f5003a9df48b53f8a81e4035d46b657b6609f8747918a46728e
# Copying blob sha256:eb5aafaed0e970f12d5d9282c1b3393844e53a07ed9653107c178ed776bcd41a
# Copying blob sha256:4d4a26ca0828609f5d4ba823e23d58ce3fd789788ff667e0cba2d79b32ba2d1f
# Copying blob sha256:7aba3d8e121791acd917b34cacd71bad7e0ad0b0ca7d658ee7f8492483b72ccf
# Copying blob sha256:e5c16916406424fe6d311af3179745ea7e15f65a61c8a2c95ed567345870695b
# Copying blob sha256:d7f7e5b73fec6e31444dd28effbfa17adec4c125be3abe2e1dccf84bc52576cf
# Copying config sha256:06b306932efc85693a057131e14210e62fa1babf6266d066ba75de601393d38a
# Writing manifest to image destination
# 'oci://quay.io/jburdo/my-model:v1'
