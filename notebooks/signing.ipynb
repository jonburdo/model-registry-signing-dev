# %%
# !uv pip install -q 'model-registry[signing]'

# %%
# !uv pip show model-registry
# Out:
# Using Python 3.12.9 environment at: /opt/app-root
# Name: model-registry
# Version: 0.3.7
# Location: /opt/app-root/lib/python3.12/site-packages
# Requires: aiohttp, aiohttp-retry, nest-asyncio2, pydantic, python-dateutil, typing-extensions
# Required-by:

# %%
import logging
import os
from pathlib import Path

from model_registry.signing import Signer

# %%
# registry auth (i.e. instead of ~/.docker/config.json)
os.environ["REGISTRY_AUTH_FILE"] = "/tmp/auth.json"

# %% [markdown]
# ## create signer

# %%
signer = Signer()

# %% [markdown]
# ## model signing

# %%
model_path = Path.home() / "my-model"

# %%
signer.sign_model(model_path)
# Out:
# PosixPath('/opt/app-root/src/my-model/model.sig')

# %%
signer.verify_model(model_path)

# %% [markdown]
# ## image signing

# %%
image_digest_ref = "quay.io/jburdo/my-model@sha256:c8d35b84f8b56e17224e1a234f23138754e5dba35da367036aaac58ebdf2e9c6"

# %%
signer.sign_image(image_digest_ref)

# %%
signer.verify_image(image_digest_ref)
